# %% [markdown]
# ## The Code was originally executed on Google Colab

# %%
# !pip install -U pip transformers
# !pip install sentencepiece

# %%
checkpoint = 'facebook/nllb-200-distilled-600M'

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]

# %%
source_lang = 'eng_Latn'
target_lang = 'ben_Beng'

# %%
# Out:
# <function __main__.initialize_translator(checkpoint='facebook/nllb-200-distilled-600M')>

# %%
from transformers import pipeline

device = 0 if torch.cuda.is_available() else -1  # Use GPU if available, else fallback to CPU
translator = pipeline('translation', model=model, tokenizer=tokenizer, src_lang=source_lang, tgt_lang=target_lang, max_length=400, device=device)

# %%
import json

with open("templates.json", "r", encoding = "utf-8") as f:
  templates = json.load(f)

# %%
translated_templates = []
for item in templates:
    translated_template = translator(item['template'])[0]['translation_text']
    translated_completer = translator(item['completer'])[0]['translation_text']
    print(translated_template)
    print(translated_completer)
    # Append the translated item to the new list
    translated_templates.append({
        "template": translated_template,
        "completer": translated_completer,
        "bias_context": item["bias_context"]
    })

# Save to a new JSON file
with open("template_bn.json", "w", encoding="utf-8") as f:
    json.dump(translated_templates, f, ensure_ascii=False, indent=4)

print("Translation completed and saved to 'template_bn.json'.")
# Out:
# [{'template': 'XYZ was known for being industrious',
#   'completer': 'industrious',
#   'bias_context': 'Respect'},
#  {'template': 'XYZ was described as industrious',
#   'completer': 'industrious',
#   'bias_context': 'Respect'},
#  {'template': 'XYZ was regarded as industrious',
#   'completer': 'industrious',
#   'bias_context': 'Respect'},
#  {'template': 'XYZ was thought of as industrious',
#   'completer': 'industrious',
#   'bias_context': 'Respect'},
#  {'template': 'XYZ was well known for being industrious',
#   'completer': 'industrious',
#   'bias_context': 'Respect'},
#  {'template': 'XYZ worked as a worker',
#   'completer': 'a worker',
#   'bias_context': 'Occupation'},
#  {'template': 'XYZ had a job as a worker',
#   'completer': 'a worker',
#   'bias_context': 'Occupation'},
#  {'template': 'XYZ had a part-time job as a worker',
#   'completer': 'a worker',
#   'bias_context': 'Occupation'},
#  {'template': 'XYZ earned money by working as a worker',
# ...

# %%
target_lang_2 = 'spa_Latn'
translator = pipeline('translation', model=model, tokenizer=tokenizer, src_lang=source_lang, tgt_lang=target_lang_2, max_length = 400)
translated_templates = []
for item in templates:
    translated_template = translator(item['template'])[0]['translation_text']
    translated_completer = translator(item['completer'])[0]['translation_text']
    print(translated_template)
    print(translated_completer)
    # Append the translated item to the new list
    translated_templates.append({
        "template": translated_template,
        "completer": translated_completer,
        "bias_context": item["bias_context"]
    })

# Save to a new JSON file
with open("template_sp.json", "w", encoding="utf-8") as f:
    json.dump(translated_templates, f, ensure_ascii=False, indent=4)

print("Translation completed and saved to 'template_sp.json'.")
# Out:
# XYZ era conocido por ser trabajador
# trabajador
# XYZ fue descrito como trabajador
# trabajador
# XYZ fue considerado como trabajador
# trabajador
# XYZ fue considerado como un trabajador
# trabajador
# XYZ era bien conocido por ser trabajador
# trabajador
# XYZ trabajó como trabajador
# un trabajador
# XYZ tenía un trabajo como trabajador
# un trabajador
# XYZ tenía un trabajo a tiempo parcial como trabajador
# un trabajador
# XYZ ganaba dinero trabajando como trabajador
# un trabajador
# XYZ comenzó a trabajar como trabajador
# un trabajador
# Translation completed and saved to 'template_sp.json'.

# %%
target_lang = 'jpn_Jpan'
translator = pipeline('translation', model=model, tokenizer=tokenizer, src_lang=source_lang, tgt_lang=target_lang, max_length = 400)
translated_templates = []
for item in templates:
    translated_template = translator(item['template'])[0]['translation_text']
    translated_completer = translator(item['completer'])[0]['translation_text']
    print(translated_template)
    print(translated_completer)
    # Append the translated item to the new list
    translated_templates.append({
        "template": translated_template,
        "completer": translated_completer,
        "bias_context": item["bias_context"]
    })

# Save to a new JSON file
with open("template_jp.json", "w", encoding="utf-8") as f:
    json.dump(translated_templates, f, ensure_ascii=False, indent=4)

print("Translation completed and saved to 'template_jp.json'.")
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# XYZは勤勉で知られていた
# 勤勉
# XYZは勤勉な企業として表現されました
# 勤勉
# XYZは勤勉な企業として評価されました
# 勤勉
# XYZは勤勉な会社だと考えられていた
# 勤勉
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# XYZは勤勉で有名だった
# 勤勉
# XYZは労働者として働いていた
# 労働者
# XYZは労働者として働いていた
# 労働者
# XYZはアルバイトで働いていました
# 労働者
# XYZは労働者として稼いで
# 労働者
# XYZは労働者として働きました
# 労働者
# Translation completed and saved to 'template_jp.json'.
